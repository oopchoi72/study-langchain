# %% [markdown]
# <a href="https://colab.research.google.com/github/oopchoi72/study-langchain/blob/main/basics_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part1 : Langchain 기초
# ## 1. 환경 구성
# ### 1) 라이브러리 설치

# %%
# !pip install -q langchain langchain-openai tiktoken
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 2.0 MB/s eta 0:00:00

# %% [markdown]
# https://www.notion.so/Langchain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ad282b9e76480bf8715e2f600f3f814

# %% [markdown]
# ### 2) OpenAI 인증키 설정

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-proj-"

# %% [markdown]
# https://www.notion.so/Langchain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ad282b9e76480b3a177d4d4e0658a8f

# %% [markdown]
# ## 2. LLM Chain
# ### 1) Prompt + LLM

# %%
from langchain_openai import ChatOpenAI

# model
llm = ChatOpenAI(model="gpt-3.5-turbo-0125")

# chain 실행
result = llm.invoke("지구의 자전 주기는?")

# %% [markdown]
# https://www.notion.so/Langchain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e76480ecafdaffbf96ec7ff6

# %%
result.content
# Out:
# '지구의 자전 주기는 약 24시간입니다. 이것은 지구가 자신의 축 주위를 1회 회전하는 데 소요되는 시간을 나타냅니다. 이로 인해 지구의 낮과 밤이 생기고, 일정한 주기로 일몰과 일출이 발생합니다.'

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("You are an expert in astronomy. Answer the question. : {input}")
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='You are an expert in astronomy. Answer the question. : {input}'), additional_kwargs={})])

# %% [markdown]
# https://www.notion.so/Langchain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e764803b99d6d1570022f55f

# %% [markdown]
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='You are an expert in astronomy. Answer the question. : {input}'), additional_kwargs={})])
#
# https://www.notion.so/Langchain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e76480ce9759d985bbdd122c

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125")

# chain 연결 (LCEL)
chain = prompt | llm

# chain 호출
chain.invoke({"input": "지구의 자전 주기는?"})
# Out:
# AIMessage(content='지구의 자전 주기는 약 24시간이며, 이것이 하루의 길이를 결정합니다. 이 주기는 지구의 자전축 주위를 한 번 도는 시간을 의미합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 28, 'total_tokens': 89, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CchheHOFGRglXcJvarS2BQlS109zi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--091ef163-1fca-4c18-9bf3-ec1a90dc4c33-0', usage_metadata={'input_tokens': 28, 'output_tokens': 61, 'total_tokens': 89, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# https://www.notion.so/Langchain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e76480bc9183c2aba8570db3

# %% [markdown]
# AIMessage(content='지구의 자전 주기는 약 24시간이며, 이것이 하루의 길이를 결정합니다. 이 주기는 지구의 자전축 주위를 한 번 도는 시간을 의미합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 28, 'total_tokens': 89, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CchheHOFGRglXcJvarS2BQlS109zi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--091ef163-1fca-4c18-9bf3-ec1a90dc4c33-0', usage_metadata={'input_tokens': 28, 'output_tokens': 61, 'total_tokens': 89, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
#
# https://www.notion.so/Langchain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e7648009ba0ac8c71920e5c5

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# prompt + model + output parser
prompt = ChatPromptTemplate.from_template("You are an expert in astronomy. Answer the question. : {input}")
llm = ChatOpenAI(model="gpt-3.5-turbo-0125")
output_parser = StrOutputParser()

# LCEL chanining
chain = prompt | llm | output_parser

# chain 호출
chain.invoke({"input": "지구의 자전 주기는?"})
# Out:
# '지구의 자전 주기는 약 24시간입니다. 자전 주기는 지구가 자전하는데 걸리는 시간으로, 이것이 하루동안 일어나는 낮과 밤의 변화를 만들어냅니다. 지구의 자전속도는 적도 부근에서 약 1670 km/h에 이르며, 적도에서 극지방으로 갈수록 속도는 줄어듭니다. 이러한 자전 주기는 우리가 낮과 밤을 경험하고 계절이 변화하는 원인 중 하나입니다.'

# %% [markdown]
# ### 2) Multiple Chains
#
# 1. 한국어 단어를 영어로 변환하는 체인
# 2. 1번 체인을 사용해서 만들어진 영어 단어(문자열)를 입력으로 받아서 한국어로 설명하도록 하는 체인

# %%
prompt1 = ChatPromptTemplate.from_template("translates {korean_word} to English.")
prompt2 = ChatPromptTemplate.from_template(
    "explain {english_word} using oxford dictionary to me in Korean."
)

llm = ChatOpenAI(model="gpt-3.5-turbo-0125")

chain1 = prompt1 | llm | StrOutputParser()

chain1.invoke({"korean_word": "미래"})
# Out:
# 'future'

# %%
chan2 = (
    {"english_word": chain1}
    | prompt2
    | llm
    | StrOutputParser()
)

chan2.invoke({"korean_word": "미래"})
# Out:
# '미래란 미리 예상되는 것이나 예정된 것을 가리키며, 지금과 다른 시기나 상황에 대한 시각이나 상상을 포함하거나 현실과 대조를 이룹니다.'

# %% [markdown]
# https://www.notion.so/LangChain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e7648011b21ccbbe73dc4484

# %% [markdown]
# ## 3. Prompt
# ### 1) PromtTemplate

# %%
from langchain_core.prompts import PromptTemplate

# 'name'과 'age'라는 두 개의 변수를 사용하는 프롬프트 템플릿을 정의
template_text = "안녕하세요, 제 이름은 {name}이고, 나이는 {age}살입니다."

# PromptTemplate 인스턴스를 생성
prompt_template = PromptTemplate.from_template(template_text)

# 템플릿에 값을 채워서 프롬프트를 완성
filled_prompt = prompt_template.format(name="홍길동", age=30)

filled_prompt
# Out:
# '안녕하세요, 제 이름은 홍길동이고, 나이는 30살입니다.'

# %%
# 문자열 템플릿 결합 (PromptTemplate + PromptTemplate + 문자열)
combined_prompt = (
    prompt_template
    + PromptTemplate.from_template("\n\n아버지를 아버지라 부를 수 없습니다.")
    + "\n\n{language}로 번역해주세요."
)

combined_prompt
# Out:
# PromptTemplate(input_variables=['age', 'language', 'name'], input_types={}, partial_variables={}, template='안녕하세요, 제 이름은 {name}이고, 나이는 {age}살입니다.\n\n아버지를 아버지라 부를 수 없습니다.\n\n{language}로 번역해주세요.')

# %%
combined_prompt.format(name="홍길동", age=30, language="영어")
# Out:
# '안녕하세요, 제 이름은 홍길동이고, 나이는 30살입니다.\n\n아버지를 아버지라 부를 수 없습니다.\n\n영어로 번역해주세요.'

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-3.5-turbo-0125")

chain = (
    combined_prompt
    | llm
    | StrOutputParser()
)
chain.invoke({"name": "홍길동", "age": 30, "language": "영어"})
# Out:
# 'Hello, my name is Hong Gil-dong and I am 30 years old.\n\nI cannot call my father "father."'

# %% [markdown]
# ### 2) ChatPromptTemplate

# %%
# 2-튜플 형태의 메시지 목록으로 프롬프트 생성 (type, content)

from langchain_core.prompts import ChatPromptTemplate

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "이 시스템은 천문학 질문에 답변할 수 있습니다."),
    ("user", "{user_input}")
])

messages = chat_prompt.format_messages(user_input="태양계에서 가장 큰 행성은 무엇인가요?")
messages
# Out:
# [SystemMessage(content='이 시스템은 천문학 질문에 답변할 수 있습니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='태양계에서 가장 큰 행성은 무엇인가요?', additional_kwargs={}, response_metadata={})]

# %%
chain = chat_prompt | llm | StrOutputParser()
chain.invoke({"user_input": "태양계에서 가장 큰 행성은 무엇인가요?"})
# Out:
# '태양계에서 가장 큰 행성은 목성입니다. 목성은 지름이 약 139,822 km로 태양계에서 가장 크고 무거운 행성으로 알려져 있습니다.'

# %% [markdown]
# https://www.notion.so/LangChain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e764806a82e0ff5ea10e5fae

# %% [markdown]
# ### 3) Message

# %%
# MessagePromptTemplate 활용

from langchain_core.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate

chat_prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessagePromptTemplate.from_template("이 시스템은 천문학 질문에 답변할 수 있습니다."),
        HumanMessagePromptTemplate.from_template("{user_input}")
    ]
)

messages = chat_prompt.format_messages(user_input="태양계에서 가장 큰 행성은 무엇인가요?")
messages
# Out:
# [SystemMessage(content='이 시스템은 천문학 질문에 답변할 수 있습니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='태양계에서 가장 큰 행성은 무엇인가요?', additional_kwargs={}, response_metadata={})]

# %%
chain = chat_prompt | llm | StrOutputParser()
chain.invoke({"user_input": "태양계에서 가장 큰 행성은 무엇인가요?"})
# Out:
# '태양계에서 가장 큰 행성은 목성입니다. 목성은 지름이 약 143,000 킬로미터로 태양계에서 가장 큰 행성이며, 대기로 둘러싸인 가스 행성으로 알려져 있습니다.'

# %% [markdown]
# ## 5. Model Parameter
# ### 1) 모델 클래스 유형
# LLM

# %%
from langchain_openai import OpenAI
llm = OpenAI()
llm.invoke("한국의; 대표적인 관광지 3군데를 추천해주세요.")
# Out:
# '\n1. 경복궁 - 한국의 대표적인 궁궐 중 하나로서 조선 왕조의 궁궐이었던 곳입니다. 아름다운 건물과 정원이 함께 어우러져있어 전통적인 한국의 아름다움을 느낄 수 있습니다.\n\n2. 덕수궁 - 경복궁과 함께 조선 왕조의 궁궐 중 하나로서, 서울의 시민들에게 사랑받는 곳입니다. 주변에는 청계천과 남산이 위치해 있어 경치도 좋고 산책하기에도 좋은 장소입니다.\n\n3. 제주도 - 한국의 대표적인 섬으로서 자연의 아름다움을 느낄 수 있는 곳입니다. 해변, 화산, 동굴 등 다'

# %% [markdown]
# https://www.notion.so/LangChain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e764803e99d7d10b4048695d

# %% [markdown]
# ChatModel

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

chat = ChatOpenAI()

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "이 시스템은 여행 전문가입니다."),
    ("user", "{user_input}"),
])

chain = chat_prompt | llm
chain.invoke({"user_input", "안녕하세요? 한국의 대표적인 관광지 3군데를 추천해주세요."})
# Out:
# '\nSystem: 한국의 대표적인 관광지로는 경복궁, 남산 타워, 부산 해운대 해수욕장이 있습니다. 어떤 관광지를 방문하고 싶으신가요?'

# %% [markdown]
# ### 2) 모델 파라미터 설정
# 모델에 직접 파라미터를 전달 (모델 생성 시점)

# %%
from langchain_openai import ChatOpenAI

# 모델 파라미터 설정
params = {
    "temperature": 0.7, # 생성된 텍스트의 다양성 조정
    "max_tokens": 100,  # 생성할 최대 토큰 수
}

kwargs = {
    "frequency_penalty": 0.5, # 이미 등장한 단어의 재등장 확률
    "presence_penalty": 0.5,  # 새로운 단어의 도입을 장려
    "stop": ["\n"]            # 정지 시퀀스 설정
}

# 모델 인스턴스를 생성할 때 설정
model = ChatOpenAI(
    model="gpt-3.5-turbo-0125",
    **params,
    model_kwargs = kwargs
)

# 모델 호출
question = "태양계에서 가장 큰 행성은 무엇인가요?"
response = model.invoke(question)

# 전체 응답 출력
print(response)
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3473: UserWarning: Parameters {'frequency_penalty', 'presence_penalty', 'stop'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if (await self.run_code(code, result,  async_=asy)):
# content='가장 큰 행성은 목성입니다. 목성은 태양계에서 가장 큰 질량을 가진 행성으로 알려져 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 29, 'total_tokens': 76, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CcjJ1DtgdrdKl1nbWlhiiAby7O1RR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--34076923-0fc9-4e17-8e81-7dd247492c79-0' usage_metadata={'input_tokens': 29, 'output_tokens': 47, 'total_tokens': 76, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# https://www.notion.so/LangChain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e7648097b4cac83f5037b0e6

# %% [markdown]
# 모델에 직접 파라미터를 전달 (모델 호출 시점)

# %%
# 모델 파라미터 설정
params = {
    "temperature": 0.7,
    "max_tokens": 100,
}

# 모델 인스턴스를 호출할 때 전달
response = model.invoke(question, **params)

# 문자 출력
print(response.content)
# Out:
# 태양계에서 가장 큰 행성은 목성입니다. 목성은 태양계 내에서 지름, 질량, 부피 등 다양한 측면에서 가장 큰 행성으로 알려져 있습니다.

# %% [markdown]
# 모델에 추가적인 파라미터를 전달
# - bind 메서드를 사용

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "이 시스템은 천문학 질문에 답변할 수 있습니다."),
    ("user", "{user_input}"),
])

model = ChatOpenAI(model="gpt-3.5-turbo-0125")

messages = prompt.format_messages(user_input="태양계에서 가장 큰 행성은 무엇인가요?")

before_answer = model.invoke(messages)

# binding 이전 출력
print(before_answer)

# 모델 호출 시 추가적인 인수를 전달하기 위해 bind 메서드 사용 (응답의 최대 길이를 10 토큰으로 제한)
chain = prompt | model.bind(max_tokens=10)

after_answer = chain.invoke({"user_input": "태양계에서 가장 큰 행성은 무엇인가요?"})

# binding 이후 출력
print(after_answer)
# Out:
# content='태양계에서 가장 큰 행성은 목성입니다. 목성은 태양과 가장 가까이에 위치한 가스 행성으로, 태양계에서 가장 큰 질량을 가지고 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 58, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CcjZ4sBHwVn8uuqs7tiIe7rO7wuKJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--7e818d04-9378-4f43-b074-a6bac7a9367d-0' usage_metadata={'input_tokens': 58, 'output_tokens': 66, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='태양계에서 가장 큰' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 58, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CcjZ59iD2xks7VF7zDYBrJdUqTNrZ', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None} id='run--449b7a81-7819-4e42-aec3-d5053163cc30-0' usage_metadata={'input_tokens': 58, 'output_tokens': 10, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
before_answer.content
# Out:
# '태양계에서 가장 큰 행성은 목성입니다. 목성은 태양과 가장 가까이에 위치한 가스 행성으로, 태양계에서 가장 큰 질량을 가지고 있습니다.'

# %%
after_answer.content
# Out:
# '태양계에서 가장 큰'

# %% [markdown]
# https://www.notion.so/LangChain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e7648059bc64c29dc14febd3

# %% [markdown]
# ## 6. Output Parsers
# ### 1) CSV Parser

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

output_parser = CommaSeparatedListOutputParser()
format_instructions = output_parser.get_format_instructions()

print(format_instructions)
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %% [markdown]
# https://www.notion.so/LangChain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e76480fda605ee32696889cb

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    template="List five {subject}.\n{format_instructions}",
    input_variables=["subject"],
    partial_variables={"format_instructions": format_instructions},
)

llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0)

chain = prompt | llm | output_parser

chain.invoke({"subject": "popular Korean cuisine"})
# Out:
# ['Bibimbap', 'Kimchi', 'Bulgogi', 'Japchae', 'Tteokbokki']

# %% [markdown]
# https://www.notion.so/LangChain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e7648075826afef4fa3ef23d

# %% [markdown]
# ### 2) JSON Parser

# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.pydantic_v1 import BaseModel, Field

# 자료구조 정의 (pydantic)
class CuisineRecipe(BaseModel):
  name: str = Field(description="name of a cuisine")
  recipe: str = Field(description="recipe to cook the cuisine")

# %%
# 출력 파서 정의
output_parser = JsonOutputParser(pydantic_object=CuisineRecipe)

format_instructions = output_parser.get_format_instructions()

print(format_instructions)
# Out:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"name": {"title": "Name", "description": "name of a cuisine", "type": "string"}, "recipe": {"title": "Recipe", "description": "recipe to cook the cuisine", "type": "string"}}, "required": ["name", "recipe"]}
# ```

# %%
# prompt 구성
prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": format_instructions},
)

print(prompt)
# Out:
# input_variables=['query'] input_types={} partial_variables={'format_instructions': 'The output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"name": {"title": "Name", "description": "name of a cuisine", "type": "string"}, "recipe": {"title": "Recipe", "description": "recipe to cook the cuisine", "type": "string"}}, "required": ["name", "recipe"]}\n```'} template='Answer the user query.\n{format_instructions}\n{query}\n'

# %%
chain = prompt | model | output_parser

chain.invoke({"query": "Let me know how to cook Bibimbap"})
# Out:
# {'name': 'Bibimbap',
#  'recipe': '1. Cook rice according to package instructions. 2. Prepare toppings such as sautéed vegetables, marinated beef, fried eggs, and gochujang sauce. 3. Assemble the bibimbap by placing the rice in a bowl, arranging the toppings on top, and drizzling with gochujang sauce. 4. Mix everything together before eating. Enjoy your delicious Bibimbap!'}

# %% [markdown]
# https://www.notion.so/LangChain-Basic-2ad282b9e764800cbbd1cd5bd8aa9fe8?source=copy_link#2ae282b9e7648060b548daefbcfd651f
